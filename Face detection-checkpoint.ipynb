# %%
# !pip install labelme tensorflow opencv-python matplotlib albumentations
# Out:
# Requirement already satisfied: labelme in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (5.4.1)
# Requirement already satisfied: tensorflow in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (2.15.0)
# Requirement already satisfied: opencv-python in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (3.8.2)
# Requirement already satisfied: albumentations in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (1.4.1)
# Requirement already satisfied: gdown in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (5.1.0)
# Requirement already satisfied: imgviz>=1.7.5 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (1.7.5)
# Requirement already satisfied: natsort>=7.1.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (8.4.0)
# Requirement already satisfied: numpy in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (1.26.3)
# Requirement already satisfied: onnxruntime!=1.16.0,>=1.14.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (1.17.1)
# Requirement already satisfied: Pillow>=2.8 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (10.2.0)
# Requirement already satisfied: PyYAML in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (6.0.1)
# Requirement already satisfied: qtpy!=1.11.2 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (2.4.1)
# Requirement already satisfied: scikit-image in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (0.22.0)
# Requirement already satisfied: termcolor in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (2.4.0)
# Requirement already satisfied: PyQt5!=5.15.3,!=5.15.4 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (5.15.10)
# Requirement already satisfied: colorama in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from labelme) (0.4.6)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from albumentations) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.3.2 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from albumentations) (1.3.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from albumentations) (4.9.0.80)
# Requirement already satisfied: coloredlogs in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (15.0.1)
# Requirement already satisfied: sympy in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (1.12)
# Requirement already satisfied: PyQt5-sip<13,>=12.13 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from PyQt5!=5.15.3,!=5.15.4->labelme) (12.13.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from PyQt5!=5.15.3,!=5.15.4->labelme) (5.15.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->labelme) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->labelme) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->labelme) (2024.2.12)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->labelme) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.3.2->albumentations) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.3.2->albumentations) (3.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from gdown->labelme) (4.12.2)
# Requirement already satisfied: filelock in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from gdown->labelme) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from gdown->labelme) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from gdown->labelme) (4.66.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->gdown->labelme) (2.5)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown->labelme) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown->labelme) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown->labelme) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown->labelme) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown->labelme) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime!=1.16.0,>=1.14.1->labelme) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: pyreadline3 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme) (3.4.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sweta\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)

# %%
import os
import cv2
import time
import uuid

# %%
IMAGES_PATH=os.path.join('data','images')
number_images=30

# %%
cap = cv2.VideoCapture(0)
for imgnum in range(number_images):
     print('Collecting image {}'.format(imgnum))
     ret, frame = cap.read()
     imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
     cv2.imwrite(imgname, frame)
     cv2.imshow('frame', frame)
     time.sleep(0.5)
    
     if cv2.waitKey(1) & 0xFF == ord('q'):
      break
       
cap.release()
cv2.destroyAllWindows()
# Out:
# " cap = cv2.VideoCapture(0)\nfor imgnum in range(number_images):\n     print('Collecting image {}'.format(imgnum))\n     ret, frame = cap.read()\n     imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')\n     cv2.imwrite(imgname, frame)\n     cv2.imshow('frame', frame)\n     time.sleep(0.5)\n    \n     if cv2.waitKey(1) & 0xFF == ord('q'):\n      break\n       \ncap.release()\ncv2.destroyAllWindows() "

# %%
# !labelme

# %%
import tensorflow as tf
import json
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\sweta\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\sweta\AppData\Local\Temp\ipykernel_16396\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
images= tf.data.Dataset.list_files('data\\images\\*.jpg',shuffle=False)

# %%
images.as_numpy_iterator().next() #This is done to check if the file paths is stored

# %%
def load_image(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
images = images.map(load_image)

# %%
images.as_numpy_iterator().next()

# %%
type(images)

# %%
image_generator = images.batch(4).as_numpy_iterator()

# %%
plot_images = image_generator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20),)
for idx, image in enumerate(plot_images):
    ax[idx].imshow(image)
plt.show()
# Out:
# 'fig, ax = plt.subplots(ncols=4, figsize=(20,20),)\nfor idx, image in enumerate(plot_images):\n    ax[idx].imshow(image)\nplt.show()'

# %% [markdown]
# # Now we have data, we have loaded it in model variables and now we have to do
# # train, test split but here we do it manually by making folders and cut and paste. Putting 70% in train and 15% each in test and val on random basis

# %%
#Moving the matching labels.
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):

        filename=file.split('.')[0]+'.json'
        existing_filepath = os.path.join('data', 'labels', filename)
        if os.path.exists(existing_filepath):
            new_filepath = os.path.join('data', folder, 'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %%
import albumentations as alb

# %%
img = cv2.imread(os.path.join('data','train','images','84cb5b1b-ddcd-11ee-99d2-c30c817b9ee4.jpg'))
img.shape #We will crop the size in augmentations.
# Out:
# (480, 640, 3)

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450), 
                             alb.HorizontalFlip(p=0.5), 
                             alb.RandomBrightnessContrast(p=0.2),
                             alb.RandomGamma(p=0.2), 
                             alb.RGBShift(p=0.2), 
                             alb.VerticalFlip(p=0.5)],
                        bbox_params=alb.BboxParams(format='albumentations',label_fields=['class_labels']))

# %%
img = cv2.imread(os.path.join('data','train','images','84cb5b1b-ddcd-11ee-99d2-c30c817b9ee4.jpg'))

# %%
with open(os.path.join('data', 'train', 'labels', '84cb5b1b-ddcd-11ee-99d2-c30c817b9ee4.json'), 'r') as f:
       label = json.load(f)

# %%
label['shapes'][0]['points']
# Out:
# [[314.18604651162786, 132.7325581395349],
#  [485.6976744186046, 344.94186046511624]]

# %%
coords = [0,0,0,0]
coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]

# %%
coords #pascal_voc format of coordiinates
# Out:
# [314.18604651162786, 132.7325581395349, 485.6976744186046, 344.94186046511624]

# %%
coords = list(np.divide(coords, [640,480,640,480])) #albumentation format of coordinates

# %%
coords
# Out:
# [0.49091569767441856,
#  0.2765261627906977,
#  0.7589026162790697,
#  0.7186288759689922]

# %%
augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])

# %%
augmented['bboxes']
# Out:
# [(0.19622739018087865,
#   0.2416279069767442,
#   0.5773643410852713,
#   0.713204134366925)]

# %%
cv2.rectangle(augmented['image'], 
              tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [450,450]).astype(int)), 
                        (255,0,0), 2)
    
plt.imshow(augmented['image'])

# %%
for partition in ['train','test','val']: \n",
        for image in os.listdir(os.path.join('data', partition, 'images')):
            img = cv2.imread(os.path.join('data', partition, 'images', image))

            coords = [0,0,0.00001,0.00001]
            label_path = os.path.join('data', partition, 'labels', f'{image.split(\".\")[0]}.json')
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                   label = json.load(f)
    
                coords[0] = label['shapes'][0]['points'][0][0]\n",
                coords[1] = label['shapes'][0]['points'][0][1]\n",
                coords[2] = label['shapes'][0]['points'][1][0]\n",
                coords[3] = label['shapes'][0]['points'][1][1]\n",
               coords = list(np.divide(coords, [640,480,640,480]))\n",
    
            try: \n",
                for x in range(60):\n",
                    augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])\n",
                    cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(\".\")[0]}.{x}.jpg'), augmented['image'])\n",
    
                   annotation = {}
               annotation['image'] = image,
    
                    if os.path.exists(label_path):
                        if len(augmented['bboxes']) == 0: 
                            annotation['bbox'] = [0,0,0,0]
                            annotation['class'] = 0 
                  
                            annotation['bbox'] = augmented['bboxes'][0]\n",
                            annotation['class'] = 1\n",
                    else: \n",
                        annotation['bbox'] = [0,0,0,0]\n",
                        annotation['class'] = 0 \n",
    
    
                    with open(os.path.join('aug_data', partition, 'labels', f'{image.split(\".\")[0]}.{x}.json'), 'w') as f:\n",
                        json.dump(annotation, f)\n",
    
            except Exception as e:\n",
                print(e)"
# Out:
#   File <tokenize>:15
#     coords = list(np.divide(coords, [640,480,640,480]))\n",
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
for partition in ['train','test','val']:
        for image in os.listdir(os.path.join('data', partition, 'images')):
            img = cv2.imread(os.path.join('data', partition, 'images', image))
    
            coords = [0,0,0.00001,0.00001]
            label_path = os.path.join('data', partition, 'labels', f'{image.split(\".\")[0]}.json')
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    label = json.load(f)

                coords[0] = label['shapes'][0]['points'][0][0]
                coords[1] = label['shapes'][0]['points'][0][1]
                coords[2] = label['shapes'][0]['points'][1][0]
                coords[3] = label['shapes'][0]['points'][1][1]
                coords = list(np.divide(coords, [640,480,640,480]))
    
            try: \n",
                for x in range(60):\n",
                    augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                    cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(\".\")[0]}.{x}.jpg'), augmented['image'])
    
                    annotation = {}
                    annotation['image'] = image
    
                    if os.path.exists(label_path):
                        if len(augmented['bboxes']) == 0: 
                            annotation['bbox'] = [0,0,0,0]
                            annotation['class'] = 0 
                        else: 
                            annotation['bbox'] = augmented['bboxes'][0]
                            annotation['class'] = 
                    else: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
    
    
                    with open(os.path.join('aug_data', partition, 'labels', f'{image.split()[0]}.{x}.json'), 'w') as f:
                        json.dump(annotation, f)
    
            except Exception as e:
                print(e)
# Out:
#   Cell In[55], line 6
#     label_path = os.path.join('data', partition, 'labels', f'{image.split(\".\")[0]}.json')
#                                                                                           ^
# SyntaxError: f-string expression part cannot include a backslash
